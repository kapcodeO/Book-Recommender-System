# %% [markdown]
# ## **Research Notebook for Book Recommender :**

# %%
import pandas as pd
import numpy as np

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to /Users/kapilojha/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kapilojha/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ### **Exploratory Data Analysis :**

# %%
# read in the data
books = pd.read_csv("/Users/kapilojha/Desktop/ml/projects/book-recommender/data/books.csv",
                encoding="latin-1",
                on_bad_lines="skip",
                sep=";",
                low_memory=False
        )

# %%
# !ls
# Out:
# research.ipynb

# %%
# view the data
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
print("Large URl: ", books["Image-URL-L"].iloc[0])
print("Medium URl: ", books["Image-URL-M"].iloc[0])
print("Small URl: ", books["Image-URL-S"].iloc[0])
# Out:
# Large URl:  http://images.amazon.com/images/P/0195153448.01.LZZZZZZZ.jpg
# Medium URl:  http://images.amazon.com/images/P/0195153448.01.MZZZZZZZ.jpg
# Small URl:  http://images.amazon.com/images/P/0195153448.01.THUMBZZZ.jpg

# %% [markdown]
# Each book has 3 diffrent Image url :
# - depending on our requirements we can choose any of the three
# - small, medium and large.

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
books.shape
# Out:
# (271360, 8)

# %% [markdown]
# We have total of 2,71,360 rows and 8 features.
#
# Since we do not need the small and medium url's we should remove them from
# our dataset.

# %%
books.drop(["Image-URL-S", "Image-URL-M"],
           axis=1,
           inplace=True)
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
# rename the column names for easier processing
books.rename(columns={
    "ISBN" : "isbn",
    "Book-Title" : "title",
    "Book-Author" : "author",
    "Year-Of-Publication" : "year",
    "Publisher" : "publisher",
    "Image-URL-L" : "image-url"
}, inplace=True)
books.head()
# Out:
#          isbn                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  author  year                   publisher  \
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
#
#                                            image-url
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
# import users data
users = pd.read_csv("/Users/kapilojha/Desktop/ml/projects/book-recommender/data/users.csv",
                    sep=";",
                    encoding="latin-1",
                    on_bad_lines="skip")
users["Age"] = users["Age"].bfill()
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa  18.0
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia  17.0
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom  61.0

# %%
# rename users columns for easier processing
users.rename(columns={
    "User-ID" : "id",
    "Location" : "location",
    "Age" : "age"
}, inplace=True)

# %%
users.head()
# Out:
#    id                            location   age
# 0   1                  nyc, new york, usa  18.0
# 1   2           stockton, california, usa  18.0
# 2   3     moscow, yukon territory, russia  17.0
# 3   4           porto, v.n.gaia, portugal  17.0
# 4   5  farnborough, hants, united kingdom  61.0

# %%
# import the book ratings data
ratings = pd.read_csv("/Users/kapilojha/Desktop/ml/projects/book-recommender/data/ratings.csv",
                      sep=";",
                      encoding="latin-1",
                      on_bad_lines="skip")
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
# rename ratings columns names for easier processing
ratings.rename(columns={
    "User-ID" : "id",
    "ISBN" : "isbn",
    "Book-Rating" : "rating"
}, inplace=True)
ratings.head()
# Out:
#        id        isbn  rating
# 0  276725  034545104X       0
# 1  276726  0155061224       5
# 2  276727  0446520802       0
# 3  276729  052165615X       3
# 4  276729  0521795028       6

# %%
# view the data shapes together
print(books.shape, users.shape, ratings.shape)
# Out:
# (271360, 6) (278858, 3) (1149780, 3)

# %%
# no. of books an individual user read
ratings["id"].value_counts()[:10]
# Out:
# id
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
# 212898     4785
# 278418     4533
# 76352      3367
# 110973     3100
# 235105     3067
# Name: count, dtype: int64

# %% [markdown]
# As you can see `user 11676` has read `13,602 books`.

# %%
# users who have at least read more than 200 books
x = ratings["id"].value_counts() > 200

# %%
x.value_counts()
# Out:
# count
# False    104384
# True        899
# Name: count, dtype: int64

# %% [markdown]
# We can see only 899 users have read more than 200 books.

# %%
# extracting those users id's 
y = x[x].index
y
# Out:
# Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352, 110973,
#        235105,
#        ...
#        260183,  73681,  44296, 155916,   9856, 274808,  28634,  59727, 268622,
#        188951],
#       dtype='int64', name='id', length=899)

# %%
# select only those rows with people who read more than 200 books in ratings dataset
ratings = ratings[ratings["id"].isin(y)]
ratings.head()
# Out:
#           id        isbn  rating
# 1456  277427  002542730X      10
# 1457  277427  0026217457       0
# 1458  277427  003008685X       8
# 1459  277427  0030615321       0
# 1460  277427  0060002050       0

# %%
books.head()
# Out:
#          isbn                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  author  year                   publisher  \
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
#
#                                            image-url
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
users.head()
# Out:
#    id                            location   age
# 0   1                  nyc, new york, usa  18.0
# 1   2           stockton, california, usa  18.0
# 2   3     moscow, yukon territory, russia  17.0
# 3   4           porto, v.n.gaia, portugal  17.0
# 4   5  farnborough, hants, united kingdom  61.0

# %%
ratings.head()
# Out:
#           id        isbn  rating
# 1456  277427  002542730X      10
# 1457  277427  0026217457       0
# 1458  277427  003008685X       8
# 1459  277427  0030615321       0
# 1460  277427  0060002050       0

# %%
# merge the ratings with books dataset using isbn number
ratings_with_books = ratings.merge(books, on="isbn")
ratings_with_books.head()
# Out:
#        id        isbn  rating  \
# 0  277427  002542730X      10
# 1  277427  0026217457       0
# 2  277427  003008685X       8
# 3  277427  0030615321       0
# 4  277427  0060002050       0
#
#                                                title                 author  \
# 0  Politically Correct Bedtime Stories: Modern Ta...      James Finn Garner
# 1                 Vegetarian Times Complete Cookbook             Lucy  Moll
# 2                                           Pioneers  James Fenimore Cooper
# 3   Ask for May, Settle for June (A Doonesbury book)          G. B. Trudeau
# 4                  On a Wicked Dawn (Cynster Novels)      Stephanie Laurens
#
#    year                  publisher  \
# 0  1994  John Wiley &amp; Sons Inc
# 1  1995      John Wiley &amp; Sons
# 2  1974           Thomson Learning
# 3  1982        Henry Holt &amp; Co
# 4  2002                 Avon Books
#
#                                            image-url
# 0  http://images.amazon.com/images/P/002542730X.0...
# 1  http://images.amazon.com/images/P/0026217457.0...
# 2  http://images.amazon.com/images/P/003008685X.0...
# 3  http://images.amazon.com/images/P/0030615321.0...
# 4  http://images.amazon.com/images/P/0060002050.0...

# %%
# create a dataframe with book title and no. of review of that titled book
number_of_ratings_per_book = ratings_with_books.groupby("title")["rating"].count().reset_index()
number_of_ratings_per_book.rename(columns={"rating" : "total_ratings"}, inplace=True)
number_of_ratings_per_book.head()
# Out:
#                                                title  total_ratings
# 0   A Light in the Storm: The Civil War Diary of ...              2
# 1                              Always Have Popsicles              1
# 2               Apple Magic (The Collector's series)              1
# 3   Beyond IBM: Leadership Marketing and Finance ...              1
# 4   Clifford Visita El Hospital (Clifford El Gran...              1

# %%
# create a final dataset called book_ratings with the above dataset
book_ratings = ratings_with_books.merge(number_of_ratings_per_book, on="title")
book_ratings.head()
# Out:
#        id        isbn  rating  \
# 0  277427  002542730X      10
# 1  277427  0026217457       0
# 2  277427  003008685X       8
# 3  277427  0030615321       0
# 4  277427  0060002050       0
#
#                                                title                 author  \
# 0  Politically Correct Bedtime Stories: Modern Ta...      James Finn Garner
# 1                 Vegetarian Times Complete Cookbook             Lucy  Moll
# 2                                           Pioneers  James Fenimore Cooper
# 3   Ask for May, Settle for June (A Doonesbury book)          G. B. Trudeau
# 4                  On a Wicked Dawn (Cynster Novels)      Stephanie Laurens
#
#    year                  publisher  \
# 0  1994  John Wiley &amp; Sons Inc
# 1  1995      John Wiley &amp; Sons
# 2  1974           Thomson Learning
# 3  1982        Henry Holt &amp; Co
# 4  2002                 Avon Books
#
#                                            image-url  total_ratings
# 0  http://images.amazon.com/images/P/002542730X.0...             82
# 1  http://images.amazon.com/images/P/0026217457.0...              7
# 2  http://images.amazon.com/images/P/003008685X.0...              1
# 3  http://images.amazon.com/images/P/0030615321.0...              1
# 4  http://images.amazon.com/images/P/0060002050.0...             13

# %%
# use only that rows which have more than 50 ratings per book
book_ratings = book_ratings[book_ratings["total_ratings"] >= 50]
book_ratings.head()
# Out:
#         id        isbn  rating  \
# 0   277427  002542730X      10
# 13  277427  0060930535       0
# 15  277427  0060934417       0
# 18  277427  0061009059       9
# 24  277427  006440188X       0
#
#                                                 title  \
# 0   Politically Correct Bedtime Stories: Modern Ta...
# 13                      The Poisonwood Bible: A Novel
# 15                                 Bel Canto: A Novel
# 18  One for the Money (Stephanie Plum Novels (Pape...
# 24                                  The Secret Garden
#
#                      author  year                  publisher  \
# 0         James Finn Garner  1994  John Wiley &amp; Sons Inc
# 13       Barbara Kingsolver  1999                  Perennial
# 15             Ann Patchett  2002                  Perennial
# 18          Janet Evanovich  1995                HarperTorch
# 24  Frances Hodgson Burnett  1998               HarperTrophy
#
#                                             image-url  total_ratings
# 0   http://images.amazon.com/images/P/002542730X.0...             82
# 13  http://images.amazon.com/images/P/0060930535.0...            133
# 15  http://images.amazon.com/images/P/0060934417.0...            108
# 18  http://images.amazon.com/images/P/0061009059.0...            108
# 24  http://images.amazon.com/images/P/006440188X.0...             79

# %%
print("Total no. of rows:", book_ratings.shape[0])
# Out:
# Total no. of rows: 61853

# %%
# drop the duplicate rows
book_ratings.drop_duplicates(["id", "title"], inplace=True)
book_ratings.head()
# Out:
#         id        isbn  rating  \
# 0   277427  002542730X      10
# 13  277427  0060930535       0
# 15  277427  0060934417       0
# 18  277427  0061009059       9
# 24  277427  006440188X       0
#
#                                                 title  \
# 0   Politically Correct Bedtime Stories: Modern Ta...
# 13                      The Poisonwood Bible: A Novel
# 15                                 Bel Canto: A Novel
# 18  One for the Money (Stephanie Plum Novels (Pape...
# 24                                  The Secret Garden
#
#                      author  year                  publisher  \
# 0         James Finn Garner  1994  John Wiley &amp; Sons Inc
# 13       Barbara Kingsolver  1999                  Perennial
# 15             Ann Patchett  2002                  Perennial
# 18          Janet Evanovich  1995                HarperTorch
# 24  Frances Hodgson Burnett  1998               HarperTrophy
#
#                                             image-url  total_ratings
# 0   http://images.amazon.com/images/P/002542730X.0...             82
# 13  http://images.amazon.com/images/P/0060930535.0...            133
# 15  http://images.amazon.com/images/P/0060934417.0...            108
# 18  http://images.amazon.com/images/P/0061009059.0...            108
# 24  http://images.amazon.com/images/P/006440188X.0...             79

# %%
print("Total no. of rows:", book_ratings.shape[0])
# Out:
# Total no. of rows: 59850

# %%
# check how many null values are still there in the dataset
book_ratings.isna().sum()
# Out:
# id               0
# isbn             0
# rating           0
# title            0
# author           0
# year             0
# publisher        0
# image-url        0
# total_ratings    0
# dtype: int64

# %%
book_ratings["title"].isna().sum()
# Out:
# np.int64(0)

# %%
# initialize stopwords
stop_words = set(stopwords.words("english"))

# preprocessing the title column for easier search
book_ratings_title = book_ratings["title"]
processed_titles = []
for title in book_ratings_title.values:
    tokens = word_tokenize(title)
    tokens = [token.lower() for token in tokens if token not in stop_words]
    result = " ".join(tokens)
    processed_titles.append(result)

processed_titles
# Out:
# ['politically correct bedtime stories : modern tales our life times',
#  'the poisonwood bible : a novel',
#  'bel canto : a novel',
#  'one money ( stephanie plum novels ( paperback ) )',
#  'the secret garden',
#  'the tao pooh',
#  'girl hyacinth blue',
#  'chocolat',
#  'the secret life bees',
#  'three to get deadly : a stephanie plum novel ( a stephanie plum novel )',
#  "full tilt ( janet evanovich 's full series )",
#  'lucky : a memoir',
#  'the dogs babel ( today show book club # 12 )',
#  "white oleander : a novel ( oprah 's book club )",
#  'white oleander : a novel',
#  'the jester',
#  'the lovely bones : a novel',
#  'me talk pretty one day',
#  'naked',
#  'the hobbit : the enchanting prelude the lord rings',
#  'a prayer owen meany',
#  'silent witness',
#  'no safe place',
#  'the murder book',
#  'middlesex : a novel',
#  'postmortem',
#  'all that remains ( kay scarpetta mysteries ( paperback ) )',
#  'the rainmaker',
#  "tuesdays morrie : an old man , young man , life 's greatest lesson",
#  'into wild',
#  'oryx crake',
#  'the da vinci code',
#  'lord flies',
#  'watchers',
#  'mortal fear',
#  'lightning',
#  'the cardinal kremlin ( jack ryan novels )',
#  'rules prey',
#  'mind prey',
#  "from potter 's field",
#  'contagion',
#  'cause death',
#  'certain prey',
#  'black notice',
#  'harry potter chamber secrets ( book 2 )',
#  'harry potter prisoner azkaban ( book 3 )',
#  "harry potter sorcerer 's stone ( book 1 )",
#  'the promise',
#  'secrets',
#  'wanderlust',
#  'guardian angel',
#  'vanished',
#  'the partner',
#  'the street lawyer',
#  'tell no one',
#  'the summons',
#  'presumed innocent',
#  'blood work',
#  'hide & amp ; seek',
#  'jack & amp ; jill ( alex cross novels )',
#  'unspeakable',
#  'saving faith',
#  'violets are blue',
#  'j is judgment',
#  'k is killer ( kinsey millhone mysteries ( paperback ) )',
#  'misery',
#  'dolores claiborne',
#  'the edge',
#  'heaven earth ( three sisters island trilogy )',
#  'hemlock bay',
#  'the prince tides',
#  'd is deadbeat ( kinsey millhone mysteries ( paperback ) )',
#  'where red fern grows',
#  'e is evidence : a kinsey millhone mystery ( kinsey millhone mysteries ( paperback ) )',
#  'b is burglar ( kinsey millhone mysteries ( paperback ) )',
#  'c is corpse ( kinsey millhone mysteries ( paperback ) )',
#  'long after midnight',
#  'the alienist',
#  'one door away heaven',
#  'reap wind',
#  'by light moon',
#  "the sweet potato queens ' book love",
#  'two dough',
#  'the god small things',
#  'flesh blood',
#  'a year provence',
#  'midnight garden good evil',
#  "angela 's ashes ( mmp ) : a memoir",
#  'the sands time',
#  'if only it were true',
#  'pay it forward',
#  "the kitchen god 's wife",
#  'saint maybe',
#  'a patchwork planet',
#  'wild animus',
#  'tears giraffe ( no.1 ladies detective agency )',
#  "the no . 1 ladies ' detective agency ( today show book club # 8 )",
#  'the queen damned ( vampire chronicles ( paperback ) )',
#  'while i was gone',
#  'night prey',
#  'chromosome 6',
#  'point origin',
#  'the street lawyer',
#  'the testament',
#  'when wind blows',
#  "a thousand acres ( ballantine reader 's circle )",
#  'all creatures great small',
#  'ashes ashes',
#  'fear nothing',
#  'seize night',
#  "she 's come undone ( oprah 's book club ( paperback ) )",
#  "i 'll be seeing you",
#  'artemis fowl ( artemis fowl , book 1 )',
#  'the five people you meet heaven',
#  'all i really need know',
#  'wild animus',
#  'disclosure',
#  'dark rivers heart',
#  'whirlwind ( tyler , book 1 )',
#  'rainbow six',
#  'mystic river',
#  'shadow prey',
#  'the sum all fears ( jack ryan novels )',
#  "tom clancy 's op-center ( tom clancy 's op center ( paperback ) )",
#  "hornet 's nest",
#  'chromosome 6',
#  'a time kill',
#  'heartbeat',
#  'the client',
#  'the pelican brief',
#  "smilla 's sense snow",
#  'the horse whisperer',
#  'presumed innocent',
#  'violets are blue',
#  '2nd chance',
#  'alaska',
#  'pet sematary',
#  'four past midnight',
#  'fat tuesday',
#  'fear nothing',
#  'one door away heaven',
#  'reap wind',
#  'hideaway',
#  "we 'll meet again",
#  'mercy',
#  'men are mars , women are venus : a practical guide improving communication getting what you want your relationships',
#  "charlotte 's web ( trophy newbery )",
#  "songs ordinary time ( oprah 's book club ( paperback ) )",
#  'at home mitford ( the mitford years )',
#  'matilda',
#  'the little prince',
#  'coming home',
#  'welcome temptation',
#  'the vampire lestat ( vampire chronicles , book ii )',
#  'beloved',
#  "the princess bride : s morgenstern 's classic tale true love high adventure",
#  'a prayer owen meany',
#  "foucault 's pendulum",
#  'rising sun',
#  'degree guilt',
#  'icebound',
#  'the witching hour ( lives mayfair witches )',
#  'the tale body thief ( vampire chronicles ( paperback ) )',
#  'disclosure',
#  'sleepers',
#  'the genesis code',
#  'irish hearts',
#  'whirlwind ( tyler , book 1 )',
#  'a man full',
#  'a lesson before dying ( vintage contemporaries ( paperback ) )',
#  'ellen foster',
#  'a heartbreaking work staggering genius',
#  'watership down',
#  'the thorn birds',
#  "dr. atkins ' new diet revolution",
#  'american gods',
#  "the book ruth ( oprah 's book club ( paperback ) )",
#  'no greater love',
#  'vanished',
#  'like water chocolate : a novel monthly installments , with recipes , romances , home remedies',
#  'the street lawyer',
#  'into thin air : a personal account mt . everest disaster',
#  'a painted house',
#  'balzac little chinese seamstress : a novel',
#  'the phantom tollbooth',
#  'dragon tears',
#  'the cardinal kremlin ( jack ryan novels )',
#  'midnight',
#  'the hunt red october',
#  'hideaway',
#  'turtle moon',
#  'fatal cure',
#  'the body farm',
#  'acceptable risk',
#  'invasion',
#  'sudden prey',
#  'executive orders ( jack ryan novels )',
#  'breathing lessons',
#  'rainbow six',
#  'big trouble',
#  'purity death',
#  'family album',
#  'the promise',
#  'secrets',
#  'wanderlust',
#  'red dragon',
#  'daddy',
#  'the firm',
#  'a time kill',
#  'the pelican brief',
#  'a wrinkle time',
#  'the chamber',
#  'the horse whisperer',
#  'five days paris',
#  'the return journey',
#  'mirror image',
#  'summer sisters',
#  'tara road',
#  'the brethren',
#  'the kiss',
#  'to kill mockingbird',
#  "scarlett : the sequel margaret mitchell 's \\gone with wind\\ '' ''",
#  'along came spider ( alex cross novels )',
#  "the general 's daughter",
#  'the witness',
#  'the bridges madison county',
#  'unspeakable',
#  'the notebook',
#  'message bottle',
#  'slow waltz cedar bend',
#  'primary colors : a novel politics',
#  'a walk remember',
#  'standoff',
#  "where heart is ( oprah 's book club ( paperback ) )",
#  'master game',
#  'alaska',
#  'catering nobody',
#  'christine',
#  'different seasons',
#  'over edge',
#  'misery',
#  'the dead zone',
#  'the tommyknockers',
#  'the gunslinger ( the dark tower , book 1 )',
#  'pet sematary',
#  'needful things',
#  "gerald 's game",
#  'dolores claiborne',
#  'the door december',
#  'a case need',
#  'insomnia',
#  'the deep end ocean',
#  'beloved ( plume contemporary fiction )',
#  'the reef',
#  'jewels sun ( irish trilogy )',
#  "river 's end",
#  'tears moon ( irish trilogy )',
#  'carolina moon',
#  'dance upon air ( three sisters island trilogy )',
#  'the regulators',
#  'couplehood',
#  'i know why caged bird sings',
#  'the prince tides',
#  'night',
#  'where red fern grows',
#  'f is fugitive ( kinsey millhone mysteries ( paperback ) )',
#  'night sins',
#  'the clinic ( alex delaware novels ( paperback ) )',
#  'fear nothing',
#  'false memory',
#  'lake wobegon days',
#  'the first wives club movie tie in',
#  'my gal sunday',
#  'hearts in atlantis',
#  'night whispers',
#  'waiting exhale',
#  'the color purple',
#  'garden of shadows ( dollanger saga ( paperback ) )',
#  'dawn ( cutler )',
#  'loves music , loves dance',
#  'moonlight becomes you',
#  'a cry in the night',
#  'sole survivor',
#  'if tomorrow comes',
#  'if only it were true',
#  'dreamcatcher',
#  "daddy 's little girl",
#  'artemis fowl ( artemis fowl , book 1 )',
#  "do n't stand too close naked man",
#  'all i really need know',
#  'dangerous',
#  'call wild',
#  'the poisonwood bible : a novel',
#  'the alchemist : a fable about following your dream',
#  "bridget jones 's diary",
#  'bridget jones : the edge reason',
#  'chocolat',
#  'matilda',
#  'the secret life bees',
#  'the hours : a novel',
#  'white oleander : a novel',
#  'the catcher rye',
#  'me talk pretty one day',
#  'the mists avalon',
#  'the witching hour ( lives mayfair witches )',
#  'the cider house rules',
#  'table for two',
#  'house sand fog',
#  'the amber spyglass ( his dark materials , book 3 )',
#  'the golden compass ( his dark materials , book 1 )',
#  'the subtle knife ( his dark materials , book 2 )',
#  'neverwhere',
#  'american gods',
#  'coraline',
#  'like water chocolate : a novel monthly installments recipes , romances , home remedies',
#  "the bonesetter 's daughter",
#  'lord flies',
#  'the accidental tourist',
#  'fatal cure',
#  'harry potter chamber secrets ( book 2 )',
#  'harry potter prisoner azkaban ( book 3 )',
#  'harry potter goblet fire ( book 4 )',
#  'harry potter order phoenix ( book 5 )',
#  'circle friends',
#  'good omens',
#  'neuromancer ( remembering tomorrow )',
#  'the sands time',
#  'a bend road',
#  'the notebook',
#  'thinner',
#  'pet sematary',
#  'the dark half',
#  '1984',
#  'animal farm',
#  'girl pearl earring',
#  'rising tides',
#  'face fire ( three sisters island trilogy )',
#  "the clan cave bear ( earth 's children ( paperback ) )",
#  'the valley horses',
#  'sacred sins',
#  "harry potter sorcerer 's stone ( book 1 )",
#  'the fellowship ring ( the lord rings , part 1 )',
#  'the two towers ( the lord rings , part 2 )',
#  "she 's come undone ( oprah 's book club )",
#  'night whispers',
#  'possession : a romance',
#  'snow falling cedars',
#  "angela 's ashes ( mmp ) : a memoir",
#  "angela 's ashes",
#  'the shipping news : a novel',
#  'the joy luck club',
#  "the kitchen god 's wife",
#  'the eight',
#  'the tale body thief ( vampire chronicles ( paperback ) )',
#  'disclosure',
#  'the apprentice',
#  'watership down',
#  'skipping christmas',
#  'contagion',
#  'cause death',
#  'southern cross',
#  'isle dogs',
#  'the gift',
#  'the runaway jury',
#  'the brethren',
#  'the king torts',
#  'roses are red ( alex cross novels )',
#  'when wind blows',
#  'cradle all',
#  '2nd chance',
#  "the handmaid 's tale",
#  'misery',
#  'thinner',
#  'the dark half',
#  'insomnia',
#  'the valley horses',
#  'the bourne supremacy',
#  'the bourne ultimatum',
#  'dust dust',
#  'touching evil',
#  "the hitchhiker 's guide galaxy",
#  'midnight garden good evil : a savannah story',
#  'nickel dimed : on ( not ) getting by america',
#  'stupid white men ... other sorry excuses state nation !',
#  'five quarters orange',
#  'matilda',
#  'chocolat',
#  'the secret life bees',
#  'the hours : a novel',
#  "white oleander : a novel ( oprah 's book club )",
#  'the lovely bones : a novel',
#  'me talk pretty one day',
#  'congo',
#  'intensity',
#  "the hitchhiker 's guide galaxy",
#  'watership down',
#  "it 's always something",
#  'into wild',
#  'skipping christmas',
#  'big trouble',
#  'strangers',
#  'daddy',
#  'circle friends',
#  'the copper beech',
#  'the pelican brief',
#  'the giver ( 21st century reference )',
#  'the glass lake',
#  'the long road home',
#  'the brethren',
#  'tales fourth grade nothing',
#  'a wrinkle in time',
#  'to kill mockingbird',
#  'slow waltz cedar bend',
#  'message bottle',
#  'a bend road',
#  'seabiscuit : an american legend',
#  'over edge',
#  'a case need',
#  'a is alibi ( kinsey millhone mysteries ( paperback ) )',
#  'shipping news',
#  'the color purple',
#  'snow falling cedars',
#  "angela 's ashes",
#  'pay it forward',
#  'at home mitford ( the mitford years )',
#  'lucky man : a memoir',
#  'angels',
#  'wild animus',
#  'call wild',
#  "the color water : a black man 's tribute his white mother",
#  'stupid white men ... other sorry excuses state nation !',
#  'year wonders',
#  'white oleander : a novel',
#  'jurassic park',
#  'drowning ruth',
#  'breath , eyes , memory',
#  'a heartbreaking work staggering genius',
#  'balzac little chinese seamstress : a novel',
#  'stillwatch',
#  'the firm',
#  'the testament',
#  'k is killer ( kinsey millhone mysteries ( paperback ) )',
#  'misery',
#  'girl pearl earring',
#  'a man named dave : a story triumph forgiveness',
#  'the robber bride',
#  'insomnia',
#  "she 's come undone ( oprah 's book club )",
#  'wild animus',
#  'politically correct bedtime stories : modern tales our life times',
#  'watermelon',
#  'the boy next door',
#  'the poisonwood bible',
#  'the divine secrets ya-ya sisterhood : a novel',
#  'divine secrets ya-ya sisterhood : a novel',
#  'five quarters orange',
#  'little altars everywhere : a novel',
#  'wicked : the life times wicked witch west',
#  'confessions ugly stepsister : a novel',
#  'angus , thongs full-frontal snogging : confessions georgia nicolson',
#  'fried green tomatoes whistle stop cafe',
#  'the tao pooh',
#  'chocolat',
#  "the girls ' guide hunting fishing",
#  'the nanny diaries : a novel',
#  'lucky : a memoir',
#  "white oleander : a novel ( oprah 's book club )",
#  'white oleander : a novel',
#  'the lovely bones : a novel',
#  'interview vampire',
#  "the princess bride : s morgenstern 's classic tale true love high adventure",
#  'rising sun',
#  'how make american quilt',
#  'sleepers',
#  'timeline',
#  'vittorio vampire : new tales vampires',
#  "big cherry holler : a big stone gap novel ( ballantine reader 's circle )",
#  'table for two',
#  'breath , eyes , memory',
#  'plainsong ( vintage contemporaries )',
#  'midwives : a novel',
#  'empire falls',
#  'last chance saloon',
#  'the kiss',
#  'confessions shopaholic ( summer display opportunity )',
#  'shopaholic takes manhattan ( summer display opportunity )',
#  'like water chocolate : a novel monthly installments , with recipes , romances , home remedies',
#  'the pelican brief',
#  'the client',
#  'the chamber',
#  'the da vinci code',
#  'the talisman',
#  'mortal fear',
#  "tom clancy 's op-center ( tom clancy 's op center ( paperback ) )",
#  'invasion',
#  'cause death',
#  'point origin',
#  'abduction',
#  'family album',
#  'red dragon',
#  'hannibal',
#  'the testament',
#  'the brethren',
#  'daisy fay miracle man',
#  'the notebook',
#  'saving faith',
#  'fat tuesday',
#  'message bottle',
#  'the alibi',
#  "where heart is ( oprah 's book club ( paperback ) )",
#  'the honk holler opening soon',
#  'seabiscuit : an american legend',
#  'dance upon air ( three sisters island trilogy )',
#  'face fire ( three sisters island trilogy )',
#  'zen art motorcycle maintenance : an inquiry values',
#  'winter moon',
#  'body lies',
#  "bridget jones 's diary",
#  'temptation',
#  "she 's come undone ( oprah 's book club ( paperback ) )",
#  'while my pretty one sleeps',
#  'a civil action',
#  'good bed',
#  'jemima j : a novel about ugly ducklings swans',
#  "do n't sweat small stuff it 's all small stuff : simple ways keep little things taking over your life ( do n't sweat small stuff series )",
#  'all i really need know',
#  'welcome world , baby girl !',
#  'nickel dimed : on ( not ) getting by america',
#  'tribulation force : the continuing drama those left behind ( left behind no . 2 )',
#  'nicolae : the rise antichrist ( left behind no . 3 )',
#  "what expect when you 're expecting ( revised edition )",
#  'wild animus',
#  'beach house',
#  'chicken soup soul ( chicken soup soul )',
#  "chicken soup woman 's soul ( chicken soup soul series ( paper ) )",
#  'the subtle knife ( his dark materials , book 2 )',
#  'fahrenheit 451',
#  'misery',
#  'the bean trees',
#  'divine secrets ya-ya sisterhood : a novel',
#  'brave new world',
#  "songs ordinary time ( oprah 's book club ( paperback ) )",
#  "bridget jones 's diary",
#  'the secret life bees',
#  'life pi',
#  'the nanny diaries : a novel',
#  'lucky : a memoir',
#  'white oleander : a novel',
#  "white oleander : a novel ( oprah 's book club )",
#  'the lovely bones : a novel',
#  'river , cross my heart',
#  'a widow one year',
#  'while i was gone',
#  'the bluest eye',
#  'blessings',
#  'breath , eyes , memory',
#  'plainsong ( vintage contemporaries )',
#  'the reader',
#  "vinegar hill ( oprah 's book club ( paperback ) )",
#  "the book ruth ( oprah 's book club ( paperback ) )",
#  'one true thing',
#  'charming billy',
#  'into wild',
#  'drowning ruth',
#  "the bonesetter 's daughter",
#  'the pull moon',
#  'to kill mockingbird',
#  'slow waltz cedar bend',
#  "song solomon ( oprah 's book club ( paperback ) )",
#  'beloved',
#  'we were mulvaneys',
#  'falling angels',
#  'the bonfire vanities',
#  "harry potter sorcerer 's stone ( harry potter ( paperback ) )",
#  'bridget jones : the edge reason',
#  'jewel',
#  'shipping news',
#  'range motion',
#  'snow falling cedars',
#  "angela 's ashes : a memoir",
#  'stones from the river',
#  'mother pearl',
#  'the five people you meet heaven',
#  "do n't sweat small stuff it 's all small stuff : simple ways keep little things taking over your life ( do n't sweat small stuff series )",
#  'peace like river',
#  'the joy luck club',
#  "the color water : a black man 's tribute his white mother",
#  'the runaway jury',
#  'the five people you meet heaven',
#  'bel canto : a novel',
#  'to kill mockingbird',
#  'five quarters orange',
#  'wicked : the life times wicked witch west',
#  'i know this much is true',
#  "songs ordinary time ( oprah 's book club ( paperback ) )",
#  "the girls ' guide hunting fishing",
#  'year wonders',
#  'the red tent ( bestselling backlist )',
#  'the hours : a novel',
#  'the amazing adventures kavalier & amp ; clay',
#  'the nanny diaries : a novel',
#  'the cider house rules',
#  'plainsong ( vintage contemporaries )',
#  'the reader',
#  'empire falls',
#  'like water chocolate : a novel monthly installments recipes , romances , home remedies',
#  'into thin air : a personal account mt . everest disaster',
#  'the virgin suicides',
#  'beloved ( plume contemporary fiction )',
#  'vanished',
#  'girl , interrupted',
#  'midnight garden good evil',
#  'snow falling cedars',
#  "angela 's ashes : a memoir",
#  'stones from the river',
#  'cold mountain',
#  'falling angels',
#  "the color water : a black man 's tribute his white mother",
#  'about boy',
#  'high fidelity',
#  'how be good',
#  'stupid white men ... other sorry excuses state nation !',
#  'the bean trees',
#  'the poisonwood bible : a novel',
#  'fast food nation : the dark side all-american meal',
#  'little altars everywhere : a novel',
#  'wicked : the life times wicked witch west',
#  'confessions ugly stepsister : a novel',
#  'one money ( stephanie plum novels ( paperback ) )',
#  'the perfect storm : a true story men against sea',
#  'the bad beginning ( a series unfortunate events , book 1 )',
#  'the reptile room ( a series unfortunate events , book 2 )',
#  'the tao pooh',
#  "songs ordinary time ( oprah 's book club ( paperback ) )",
#  "the girls ' guide hunting fishing",
#  'slammerkin',
#  'the crimson petal white',
#  'the red tent ( bestselling backlist )',
#  'the nanny diaries : a novel',
#  'the hours : a novel',
#  'three to get deadly : a stephanie plum novel ( a stephanie plum novel )',
#  'seven up ( a stephanie plum novel )',
#  "full house ( janet evanovich 's full series )",
#  "white oleander : a novel ( oprah 's book club )",
#  'white oleander : a novel',
#  'river , cross my heart',
#  'interview vampire',
#  'the queen damned ( vampire chronicles ( paperback ) )',
#  'jurassic park',
#  'how make american quilt',
#  'the tale body thief ( vampire chronicles ( paperback ) )',
#  'the cider house rules',
#  'the lost world',
#  'timeline',
#  'the angel darkness',
#  'seabiscuit',
#  'a man full',
#  'a heartbreaking work staggering genius',
#  'house sand fog',
#  'body evidence ( kay scarpetta mysteries ( paperback ) )',
#  'cruel & amp ; unusual ( kay scarpetta mysteries ( paperback ) )',
#  "vinegar hill ( oprah 's book club ( paperback ) )",
#  'mystic river',
#  'american gods',
#  'coraline',
#  "lamb : the gospel according biff , christ 's childhood pal",
#  'like water chocolate : a novel monthly installments , with recipes , romances , home remedies',
#  'the wedding',
#  'the blind assassin',
#  'the hot zone',
#  "tuesdays morrie : an old man , young man , life 's greatest lesson",
#  'into thin air : a personal account mt . everest disaster',
#  'a painted house',
#  'the devil wears prada : a novel',
#  'the phantom tollbooth',
#  'shadow prey',
#  'dragon tears',
#  'without remorse',
#  'fatherhood',
#  'isle dogs',
#  'harry potter chamber secrets ( book 2 )',
#  'harry potter prisoner azkaban ( book 3 )',
#  'harry potter goblet fire ( book 4 )',
#  'harry potter order phoenix ( book 5 )',
#  'red dragon',
#  'the firm',
#  "smilla 's sense snow",
#  'one true thing',
#  'the runaway jury',
#  'the horse whisperer',
#  'hannibal',
#  'the partner',
#  'the smoke jumper',
#  'nerd shining armor',
#  'holes ( yearling newbery )',
#  'a wrinkle in time',
#  'a wrinkle time',
#  'good omens',
#  "the general 's daughter",
#  'the alibi',
#  "dude , where 's my country ?",
#  'sick puppy',
#  'the rescue',
#  "where heart is ( oprah 's book club ( paperback ) )",
#  "the handmaid 's tale",
#  'l is lawless',
#  'k is killer ( kinsey millhone mysteries ( paperback ) )',
#  'homecoming',
#  'a case need',
#  'insomnia',
#  'the most wanted',
#  '4 blondes',
#  'the bourne identity',
#  'night',
#  'zen art motorcycle maintenance : an inquiry values',
#  "cat 's eye",
#  'dying chocolate ( culinary mysteries ( paperback ) )',
#  'the alienist',
#  'couplehood',
#  'the grilling season',
#  'prime cut',
#  'tough cookie',
#  'reap wind',
#  "harry potter sorcerer 's stone ( harry potter ( paperback ) )",
#  "bridget jones 's diary",
#  'the secret life bees',
#  'two dough',
#  "she 's come undone ( oprah 's book club )",
#  'jewel',
#  "jewel ( oprah 's book club )",
#  'shipping news',
#  'forrest gump ( movie tie )',
#  'primary colors : a novel politics',
#  'the kiss',
#  'the god small things',
#  'a year provence',
#  'all pretty horses ( the border trilogy , vol 1 )',
#  'the english patient',
#  'snow falling cedars',
#  "angela 's ashes : a memoir",
#  'good bed',
#  'artemis fowl ( artemis fowl , book 1 )',
#  'mother pearl',
#  'lucky man : a memoir',
#  'the diary ellen rimbauer : my life rose red',
#  'the five people you meet heaven',
#  'all i really need know',
#  'it was fire when i lay down it',
#  'the joy luck club',
#  "the kitchen god 's wife",
#  'the hundred secret senses',
#  "the bonesetter 's daughter",
#  'fried green tomatoes whistle stop cafe',
#  'nickel dimed : on ( not ) getting by america',
#  "ender 's game ( ender wiggins saga ( paperback ) )",
#  'wild animus',
#  'tears giraffe ( no.1 ladies detective agency )',
#  'morality beautiful girls ( no.1 ladies detective agency )',
#  "the no . 1 ladies ' detective agency ( today show book club # 8 )",
#  'how be good',
#  'lucky : a memoir',
#  'white oleander : a novel',
#  'pop goes weasel',
#  'when wind blows',
#  'the vampire lestat ( vampire chronicles , book ii )',
#  'interview vampire',
#  'the queen damned ( vampire chronicles ( paperback ) )',
#  'rising sun',
#  'degree guilt',
#  'the tale body thief ( vampire chronicles ( paperback ) )',
#  'the angel darkness',
#  'postmortem',
#  'body evidence ( kay scarpetta mysteries ( paperback ) )',
#  'the chamber',
#  'the partner',
#  'acceptable risk',
#  "hornet 's nest",
#  'unnatural exposure',
#  'point origin',
#  'black notice',
#  'the last precinct',
#  'circle friends',
#  'the copper beech',
#  'the client',
#  'pleading guilty',
#  'kiss girls',
#  'exclusive',
#  'a darkness more than night',
#  'couplehood',
#  'the grilling season',
#  'dust dust',
#  'f is fugitive ( kinsey millhone mysteries ( paperback ) )',
#  'a thin dark line ( mysteries & amp ; horror )',
#  'prime cut',
#  'ashes ashes',
#  'you belong to me',
#  'death du jour',
#  'loves music , loves dance',
#  'all around town',
#  'moonlight becomes you',
#  'the alienist',
#  'eyes child',
#  'silent witness',
#  'the joy luck club',
#  'wicked : the life times wicked witch west',
#  'one money ( stephanie plum novels ( paperback ) )',
#  'love time cholera ( penguin great books 20th century )',
#  'at home mitford ( the mitford years )',
#  "bridget jones 's diary",
#  'icy sparks',
#  'year wonders',
#  'the secret life bees',
#  'life pi',
#  'catering nobody',
#  'the red tent ( bestselling backlist )',
#  'the nanny diaries : a novel',
#  'three to get deadly : a stephanie plum novel ( a stephanie plum novel )',
#  'four to score ( a stephanie plum novel )',
#  'high five ( a stephanie plum novel )',
#  'hot six : a stephanie plum novel ( a stephanie plum novel )',
#  'seven up ( a stephanie plum novel )',
#  'the dogs babel ( today show book club # 12 )',
#  'the jester',
#  'the lovely bones : a novel',
#  'me talk pretty one day',
#  'naked',
#  'fahrenheit 451',
#  "big stone gap : a novel ( ballantine reader 's circle )",
#  "big cherry holler : a big stone gap novel ( ballantine reader 's circle )",
#  'the surgeon',
#  'the murder book',
#  'three junes',
#  'a heartbreaking work staggering genius',
#  "lamb : the gospel according biff , christ 's childhood pal",
#  'coraline',
#  'the da vinci code',
#  'balzac little chinese seamstress : a novel',
#  'sisterhood traveling pants',
#  'house sand fog',
#  'q is quarry',
#  'outlander',
#  'roses are red ( alex cross novels )',
#  '1st die : a novel',
#  "suzanne 's diary nicholas",
#  'violets are blue',
#  '2nd chance',
#  "the sweet potato queens ' book love",
#  'two dough',
#  'the green mile',
#  "schindler 's list",
#  'miss julia speaks her mind : a novel',
#  'the other boleyn girl',
#  "everything 's eventual : 14 dark tales",
#  "what expect when you 're expecting ( revised edition )",
#  'wild animus',
#  'tears giraffe ( no.1 ladies detective agency )',
#  'morality beautiful girls ( no.1 ladies detective agency )',
#  "the color water : a black man 's tribute his white mother",
#  'prodigal summer',
#  'the bean trees',
#  'pigs heaven',
#  'divine secrets ya-ya sisterhood : a novel',
#  'little altars everywhere : a novel',
#  'wicked : the life times wicked witch west',
#  'confessions ugly stepsister : a novel',
#  'the saving graces : a novel',
#  'jacob have i loved',
#  'the bad beginning ( a series unfortunate events , book 1 )',
#  "songs ordinary time ( oprah 's book club ( paperback ) )",
#  'about boy',
#  'bridget jones : the edge reason',
#  'chocolat',
#  "bridget jones 's diary",
#  'crazy you',
#  'the nanny diaries : a novel',
#  'september',
#  'lucky : a memoir',
#  'the lovely bones : a novel',
#  'cradle all',
#  'when wind blows',
#  'me talk pretty one day',
#  'the weight water : a novel tag : author resistance strange fits passion',
#  "fortune 's rocks : a novel",
#  'flesh blood',
#  'seabiscuit',
#  'plainsong ( vintage contemporaries )',
#  'a heartbreaking work staggering genius',
#  'watership down',
#  'what looks like crazy on an ordinary day',
#  'evening class',
#  'confessions shopaholic ( summer display opportunity )',
#  'shopaholic takes manhattan ( summer display opportunity )',
#  'shopaholic ties knot',
#  'beach music',
#  "tuesdays morrie : an old man , young man , life 's greatest lesson",
#  'the king torts',
#  'sisterhood traveling pants',
#  'sanctuary',
#  'family album',
#  'harry potter chamber secrets ( book 2 )',
#  'harry potter prisoner azkaban ( book 3 )',
#  'harry potter goblet fire ( book 4 )',
#  'harry potter order phoenix ( book 5 )',
#  'echoes',
#  'circle friends',
#  'a time kill',
#  'the client',
#  'the pelican brief',
#  'one true thing',
#  'the glass lake',
#  'the return journey',
#  'summer sisters',
#  'the burden proof',
#  'daisy fay miracle man',
#  "the general 's daughter",
#  'slow waltz cedar bend',
#  'a walk remember',
#  'four blind mice',
#  "where heart is ( oprah 's book club ( paperback ) )",
#  'the honk holler opening soon',
#  'the edge',
#  'scarlet feather',
#  'a man named dave : a story triumph forgiveness',
#  'quentins',
#  "harry potter sorcerer 's stone ( harry potter ( paperback ) )",
#  "the sweet potato queens ' book love",
#  'the secret life bees',
#  'the most wanted',
#  "she 's come undone ( oprah 's book club )",
#  'garden of shadows ( dollanger saga ( paperback ) )',
#  'wifey',
#  'smart women',
#  'primary colors : a novel politics',
#  "angela 's ashes ( mmp ) : a memoir",
#  'the shipping news : a novel',
#  'good bed',
#  'under tuscan sun',
#  'lucky man : a memoir',
#  'the five people you meet heaven',
#  "do n't sweat small stuff it 's all small stuff : simple ways keep little things taking over your life ( do n't sweat small stuff series )",
#  'mother pearl',
#  'a patchwork planet',
#  'cold mountain',
#  'girl hyacinth blue',
#  'five quarters orange',
#  'the divine secrets ya-ya sisterhood : a novel',
#  'the bean trees',
#  'divine secrets ya-ya sisterhood : a novel',
#  'bel canto : a novel',
#  'fast food nation : the dark side all-american meal',
#  'little altars everywhere : a novel',
#  'wicked : the life times wicked witch west',
#  'i know this much is true',
#  'one money ( stephanie plum novels ( paperback ) )',
#  'fried green tomatoes whistle stop cafe',
#  'the testament',
#  '84 charing cross road',
#  "songs ordinary time ( oprah 's book club ( paperback ) )",
#  "bridget jones 's diary",
#  'secrets',
#  "the girls ' guide hunting fishing",
#  'girl hyacinth blue',
#  'bridget jones : the edge reason',
#  'year wonders',
#  'the secret life bees',
#  'the crimson petal white',
#  'slammerkin',
#  'the red tent ( bestselling backlist )',
#  'the hours : a novel',
#  'hard eight : a stephanie plum novel ( a stephanie plum novel )',
#  'to nines : a stephanie plum novel',
#  'the nanny diaries : a novel',
#  'the amazing adventures kavalier & amp ; clay',
#  'three to get deadly : a stephanie plum novel ( a stephanie plum novel )',
#  'four to score ( a stephanie plum novel )',
#  'high five ( a stephanie plum novel )',
#  'hot six : a stephanie plum novel ( a stephanie plum novel )',
#  'seven up ( a stephanie plum novel )',
#  'fast women',
#  "full house ( janet evanovich 's full series )",
#  "full tilt ( janet evanovich 's full series )",
#  'one money ( a stephanie plum novel )',
#  'white oleander : a novel',
#  "the pilot 's wife : a novel",
#  'the lovely bones : a novel',
#  'me talk pretty one day',
#  "fortune 's rocks : a novel",
#  'the last time they met : a novel',
#  'gorky park',
#  'the eight',
#  'how make american quilt',
#  "the hitchhiker 's guide galaxy",
#  'sleepers',
#  'the golden compass ( his dark materials , book 1 )',
#  'three junes',
#  'blessings',
#  'cold mountain : a novel',
#  'a lesson before dying ( vintage contemporaries ( paperback ) )',
#  'white teeth : a novel',
#  'plainsong ( vintage contemporaries )',
#  ...]

# %%
book_ratings["title"] = processed_titles
book_ratings.head()
# Out:
#         id        isbn  rating  \
# 0   277427  002542730X      10
# 13  277427  0060930535       0
# 15  277427  0060934417       0
# 18  277427  0061009059       9
# 24  277427  006440188X       0
#
#                                                 title  \
# 0   politically correct bedtime stories : modern t...
# 13                     the poisonwood bible : a novel
# 15                                bel canto : a novel
# 18  one money ( stephanie plum novels ( paperback ) )
# 24                                  the secret garden
#
#                      author  year                  publisher  \
# 0         James Finn Garner  1994  John Wiley &amp; Sons Inc
# 13       Barbara Kingsolver  1999                  Perennial
# 15             Ann Patchett  2002                  Perennial
# 18          Janet Evanovich  1995                HarperTorch
# 24  Frances Hodgson Burnett  1998               HarperTrophy
#
#                                             image-url  total_ratings
# 0   http://images.amazon.com/images/P/002542730X.0...             82
# 13  http://images.amazon.com/images/P/0060930535.0...            133
# 15  http://images.amazon.com/images/P/0060934417.0...            108
# 18  http://images.amazon.com/images/P/0061009059.0...            108
# 24  http://images.amazon.com/images/P/006440188X.0...             79

# %%
def process_title(title):
    ''' 
    Preprocess a single title string
    '''
    tokens = word_tokenize(title)
    tokens = [token.lower() for token in tokens if token not in stop_words]
    title = " ".join(tokens)
    return title

# %% [markdown]
# #### **🎯 Pivot Table for Collaborative Filtering :**
# Collaborative filtering works by finding similar users or similar items based on rating patterns.
# You need a matrix where you can compute similarity between:
# * Rows (item-based CF: similar books)
# * that is why we need pivot table to compute similarity between diffrent users
# * in pivot table books become index user-id become columns and ratings become values.

# %%
book_ratings.pivot_table(
    values="rating",
    index="title",
    columns="id"
)
# Out:
# id                                                  254     2276    2766    \
# title
# 1984                                                   9.0     NaN     NaN
# 1st die : a novel                                      NaN     NaN     NaN
# 2nd chance                                             NaN    10.0     NaN
# 4 blondes                                              NaN     NaN     NaN
# 84 charing cross road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# wuthering heights                                      NaN     NaN     NaN
# year wonders                                           NaN     NaN     NaN
# you belong to me                                       NaN     NaN     NaN
# zen art motorcycle maintenance : an inquiry values     NaN     NaN     NaN
# zoya                                                   NaN     NaN     NaN
#
# id                                                  2977    3363    3757    \
# title
# 1984                                                   NaN     NaN     NaN
# 1st die : a novel                                      NaN     NaN     NaN
# 2nd chance                                             NaN     NaN     NaN
# 4 blondes                                              NaN     NaN     NaN
# 84 charing cross road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# wuthering heights                                      NaN     NaN     NaN
# year wonders                                           7.0     NaN     NaN
# you belong to me                                       NaN     NaN     NaN
# zen art motorcycle maintenance : an inquiry values     NaN     0.0     NaN
# zoya                                                   NaN     NaN     NaN
#
# id                                                  4017    4385    6242    \
# title
# 1984                                                   NaN     NaN     NaN
# 1st die : a novel                                      NaN     NaN     NaN
# 2nd chance                                             NaN     NaN     NaN
# 4 blondes                                              NaN     NaN     NaN
# 84 charing cross road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# wuthering heights                                      NaN     NaN     NaN
# year wonders                                           NaN     NaN     7.0
# you belong to me                                       NaN     NaN     NaN
# zen art motorcycle maintenance : an inquiry values     NaN     NaN     NaN
# zoya                                                   NaN     NaN     NaN
#
# id                                                  6251    ...  274004  \
# title                                                       ...
# 1984                                                   NaN  ...     NaN
# 1st die : a novel                                      NaN  ...     NaN
# 2nd chance                                             NaN  ...     NaN
# 4 blondes                                              0.0  ...     NaN
# 84 charing cross road                                  NaN  ...     NaN
# ...                                                    ...  ...     ...
# wuthering heights                                      NaN  ...     NaN
# year wonders                                           NaN  ...     NaN
# you belong to me                                       NaN  ...     NaN
# zen art motorcycle maintenance : an inquiry values     0.0  ...     NaN
# zoya                                                   NaN  ...     NaN
#
# id                                                  274061  274301  274308  \
# title
# 1984                                                   NaN     NaN     NaN
# 1st die : a novel                                      NaN     NaN     NaN
# 2nd chance                                             NaN     NaN     0.0
# 4 blondes                                              NaN     NaN     NaN
# 84 charing cross road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# wuthering heights                                      NaN     NaN     0.0
# year wonders                                           NaN     NaN     NaN
# you belong to me                                       NaN     NaN     NaN
# zen art motorcycle maintenance : an inquiry values     NaN     NaN     NaN
# zoya                                                   NaN     NaN     NaN
#
# id                                                  274808  275970  277427  \
# title
# 1984                                                   NaN     0.0     NaN
# 1st die : a novel                                      NaN     NaN     NaN
# 2nd chance                                             NaN     NaN     NaN
# 4 blondes                                              NaN     NaN     NaN
# 84 charing cross road                                  NaN    10.0     NaN
# ...                                                    ...     ...     ...
# wuthering heights                                      NaN     NaN     NaN
# year wonders                                           NaN     0.0     NaN
# you belong to me                                       NaN     NaN     NaN
# zen art motorcycle maintenance : an inquiry values     NaN     0.0     NaN
# zoya                                                   NaN     NaN     NaN
#
# id                                                  277478  277639  278418
# title
# 1984                                                   NaN     NaN     NaN
# 1st die : a novel                                      NaN     NaN     NaN
# 2nd chance                                             NaN     0.0     NaN
# 4 blondes                                              NaN     NaN     NaN
# 84 charing cross road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# wuthering heights                                      NaN     NaN     NaN
# year wonders                                           NaN     NaN     NaN
# you belong to me                                       NaN     NaN     NaN
# zen art motorcycle maintenance : an inquiry values     NaN     NaN     NaN
# zoya                                                   NaN     NaN     NaN
#
# [737 rows x 888 columns]

# %%
# create a pivot table from book ratings
book_pivot = book_ratings.pivot_table(
    index="title",
    columns="id",
    values="rating"
)
book_pivot.head(10)
# Out:
# id                                                  254     2276    2766    \
# title
# 1984                                                   9.0     NaN     NaN
# 1st die : a novel                                      NaN     NaN     NaN
# 2nd chance                                             NaN    10.0     NaN
# 4 blondes                                              NaN     NaN     NaN
# 84 charing cross road                                  NaN     NaN     NaN
# \o\ '' is outlaw ''                                    NaN     NaN     NaN
# a bend road                                            0.0     NaN     7.0
# a case need                                            NaN     NaN     0.0
# a child called \it\ '' : one child 's courage s...     NaN     NaN     NaN
# a civil action                                         NaN     NaN     NaN
#
# id                                                  2977    3363    3757    \
# title
# 1984                                                   NaN     NaN     NaN
# 1st die : a novel                                      NaN     NaN     NaN
# 2nd chance                                             NaN     NaN     NaN
# 4 blondes                                              NaN     NaN     NaN
# 84 charing cross road                                  NaN     NaN     NaN
# \o\ '' is outlaw ''                                    NaN     NaN     NaN
# a bend road                                            NaN     NaN     NaN
# a case need                                            NaN     NaN     NaN
# a child called \it\ '' : one child 's courage s...     NaN     NaN     NaN
# a civil action                                         NaN     0.0     NaN
#
# id                                                  4017    4385    6242    \
# title
# 1984                                                   NaN     NaN     NaN
# 1st die : a novel                                      NaN     NaN     NaN
# 2nd chance                                             NaN     NaN     NaN
# 4 blondes                                              NaN     NaN     NaN
# 84 charing cross road                                  NaN     NaN     NaN
# \o\ '' is outlaw ''                                    NaN     NaN     NaN
# a bend road                                            NaN     NaN     NaN
# a case need                                            NaN     NaN     NaN
# a child called \it\ '' : one child 's courage s...     NaN     NaN     NaN
# a civil action                                         NaN     NaN     NaN
#
# id                                                  6251    ...  274004  \
# title                                                       ...
# 1984                                                   NaN  ...     NaN
# 1st die : a novel                                      NaN  ...     NaN
# 2nd chance                                             NaN  ...     NaN
# 4 blondes                                              0.0  ...     NaN
# 84 charing cross road                                  NaN  ...     NaN
# \o\ '' is outlaw ''                                    NaN  ...     NaN
# a bend road                                            NaN  ...     NaN
# a case need                                            0.0  ...     NaN
# a child called \it\ '' : one child 's courage s...     NaN  ...     NaN
# a civil action                                         NaN  ...     NaN
#
# id                                                  274061  274301  274308  \
# title
# 1984                                                   NaN     NaN     NaN
# 1st die : a novel                                      NaN     NaN     NaN
# 2nd chance                                             NaN     NaN     0.0
# 4 blondes                                              NaN     NaN     NaN
# 84 charing cross road                                  NaN     NaN     NaN
# \o\ '' is outlaw ''                                    NaN     8.0     NaN
# a bend road                                            NaN     NaN     NaN
# a case need                                            0.0     NaN     7.0
# a child called \it\ '' : one child 's courage s...     NaN     NaN     NaN
# a civil action                                         NaN     NaN     NaN
#
# id                                                  274808  275970  277427  \
# title
# 1984                                                   NaN     0.0     NaN
# 1st die : a novel                                      NaN     NaN     NaN
# 2nd chance                                             NaN     NaN     NaN
# 4 blondes                                              NaN     NaN     NaN
# 84 charing cross road                                  NaN    10.0     NaN
# \o\ '' is outlaw ''                                    NaN     NaN     NaN
# a bend road                                            NaN     NaN     NaN
# a case need                                            NaN     NaN     NaN
# a child called \it\ '' : one child 's courage s...     NaN     NaN     NaN
# a civil action                                         NaN     NaN     NaN
#
# id                                                  277478  277639  278418
# title
# 1984                                                   NaN     NaN     NaN
# 1st die : a novel                                      NaN     NaN     NaN
# 2nd chance                                             NaN     0.0     NaN
# 4 blondes                                              NaN     NaN     NaN
# 84 charing cross road                                  NaN     NaN     NaN
# \o\ '' is outlaw ''                                    NaN     NaN     NaN
# a bend road                                            NaN     NaN     NaN
# a case need                                            NaN     NaN     0.0
# a child called \it\ '' : one child 's courage s...     NaN     NaN     NaN
# a civil action                                         NaN     NaN     NaN
#
# [10 rows x 888 columns]

# %%
# replace the null values with 0
book_pivot = book_pivot.fillna(0)
book_pivot.head(10)
# Out:
# id                                                  254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st die : a novel                                      0.0     0.0     0.0
# 2nd chance                                             0.0    10.0     0.0
# 4 blondes                                              0.0     0.0     0.0
# 84 charing cross road                                  0.0     0.0     0.0
# \o\ '' is outlaw ''                                    0.0     0.0     0.0
# a bend road                                            0.0     0.0     7.0
# a case need                                            0.0     0.0     0.0
# a child called \it\ '' : one child 's courage s...     0.0     0.0     0.0
# a civil action                                         0.0     0.0     0.0
#
# id                                                  2977    3363    3757    \
# title
# 1984                                                   0.0     0.0     0.0
# 1st die : a novel                                      0.0     0.0     0.0
# 2nd chance                                             0.0     0.0     0.0
# 4 blondes                                              0.0     0.0     0.0
# 84 charing cross road                                  0.0     0.0     0.0
# \o\ '' is outlaw ''                                    0.0     0.0     0.0
# a bend road                                            0.0     0.0     0.0
# a case need                                            0.0     0.0     0.0
# a child called \it\ '' : one child 's courage s...     0.0     0.0     0.0
# a civil action                                         0.0     0.0     0.0
#
# id                                                  4017    4385    6242    \
# title
# 1984                                                   0.0     0.0     0.0
# 1st die : a novel                                      0.0     0.0     0.0
# 2nd chance                                             0.0     0.0     0.0
# 4 blondes                                              0.0     0.0     0.0
# 84 charing cross road                                  0.0     0.0     0.0
# \o\ '' is outlaw ''                                    0.0     0.0     0.0
# a bend road                                            0.0     0.0     0.0
# a case need                                            0.0     0.0     0.0
# a child called \it\ '' : one child 's courage s...     0.0     0.0     0.0
# a civil action                                         0.0     0.0     0.0
#
# id                                                  6251    ...  274004  \
# title                                                       ...
# 1984                                                   0.0  ...     0.0
# 1st die : a novel                                      0.0  ...     0.0
# 2nd chance                                             0.0  ...     0.0
# 4 blondes                                              0.0  ...     0.0
# 84 charing cross road                                  0.0  ...     0.0
# \o\ '' is outlaw ''                                    0.0  ...     0.0
# a bend road                                            0.0  ...     0.0
# a case need                                            0.0  ...     0.0
# a child called \it\ '' : one child 's courage s...     0.0  ...     0.0
# a civil action                                         0.0  ...     0.0
#
# id                                                  274061  274301  274308  \
# title
# 1984                                                   0.0     0.0     0.0
# 1st die : a novel                                      0.0     0.0     0.0
# 2nd chance                                             0.0     0.0     0.0
# 4 blondes                                              0.0     0.0     0.0
# 84 charing cross road                                  0.0     0.0     0.0
# \o\ '' is outlaw ''                                    0.0     8.0     0.0
# a bend road                                            0.0     0.0     0.0
# a case need                                            0.0     0.0     7.0
# a child called \it\ '' : one child 's courage s...     0.0     0.0     0.0
# a civil action                                         0.0     0.0     0.0
#
# id                                                  274808  275970  277427  \
# title
# 1984                                                   0.0     0.0     0.0
# 1st die : a novel                                      0.0     0.0     0.0
# 2nd chance                                             0.0     0.0     0.0
# 4 blondes                                              0.0     0.0     0.0
# 84 charing cross road                                  0.0    10.0     0.0
# \o\ '' is outlaw ''                                    0.0     0.0     0.0
# a bend road                                            0.0     0.0     0.0
# a case need                                            0.0     0.0     0.0
# a child called \it\ '' : one child 's courage s...     0.0     0.0     0.0
# a civil action                                         0.0     0.0     0.0
#
# id                                                  277478  277639  278418
# title
# 1984                                                   0.0     0.0     0.0
# 1st die : a novel                                      0.0     0.0     0.0
# 2nd chance                                             0.0     0.0     0.0
# 4 blondes                                              0.0     0.0     0.0
# 84 charing cross road                                  0.0     0.0     0.0
# \o\ '' is outlaw ''                                    0.0     0.0     0.0
# a bend road                                            0.0     0.0     0.0
# a case need                                            0.0     0.0     0.0
# a child called \it\ '' : one child 's courage s...     0.0     0.0     0.0
# a civil action                                         0.0     0.0     0.0
#
# [10 rows x 888 columns]

# %%
book_pivot.iloc[0]
# Out:
# id
# 254       9.0
# 2276      0.0
# 2766      0.0
# 2977      0.0
# 3363      0.0
#          ...
# 275970    0.0
# 277427    0.0
# 277478    0.0
# 277639    0.0
# 278418    0.0
# Name: 1984, Length: 888, dtype: float64

# %%
# now before training we need to
# convert pivot table to csr matrix
# which will make it more efficient to preprocess
from scipy.sparse import csr_matrix

books_sparse = csr_matrix(book_pivot)
books_sparse
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 14955 stored elements and shape (737, 888)>

# %% [markdown]
# ### **Training Model :**

# %%
# initialize the model
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm="brute",
                        metric="cosine")

# %%
# fit the model
model.fit(books_sparse)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
book_pivot.iloc[237, :]
# Out:
# id
# 254       9.0
# 2276      0.0
# 2766      0.0
# 2977      0.0
# 3363      0.0
#          ...
# 275970    0.0
# 277427    0.0
# 277478    0.0
# 277639    0.0
# 278418    0.0
# Name: harry potter goblet fire ( book 4 ), Length: 888, dtype: float64

# %%
distance, suggestion = model.kneighbors(book_pivot.iloc[237, :].values.reshape(1, -1),
                                        n_neighbors=6)

# %%
distance
# Out:
# array([[0.        , 0.36914631, 0.42346873, 0.45015559, 0.58315122,
#         0.64810686]])

# %%
suggestion
# Out:
# array([[237, 239, 236, 238, 240, 241]])

# %%
suggested_books = [book_pivot.index[suggestion[i]] for i in range(len(suggestion))]
suggested_books
# Out:
# [Index(['harry potter goblet fire ( book 4 )',
#         'harry potter prisoner azkaban ( book 3 )',
#         'harry potter chamber secrets ( book 2 )',
#         'harry potter order phoenix ( book 5 )',
#         'harry potter sorcerer 's stone ( book 1 )',
#         'harry potter sorcerer 's stone ( harry potter ( paperback ) )'],
#        dtype='object', name='title')]

# %%
# book names idx : book name
book_names = {}
for idx, name in enumerate(book_pivot.index):
    book_names[idx] = name

# %%
for idx in suggestion[0]:
    print(book_names[idx])
# Out:
# harry potter goblet fire ( book 4 )
# harry potter prisoner azkaban ( book 3 )
# harry potter chamber secrets ( book 2 )
# harry potter order phoenix ( book 5 )
# harry potter sorcerer 's stone ( book 1 )
# harry potter sorcerer 's stone ( harry potter ( paperback ) )

# %% [markdown]
# #### **How to extract the image URL :**

# %%
np.where(book_pivot.index == "4 blondes")[0][0]
# Out:
# np.int64(3)

# %%
ids = np.where(book_ratings["title"] == "harry potter prisoner azkaban ( book 3 )")[0][0]

# %%
book_ratings.iloc[ids]["image-url"]
# Out:
# 'http://images.amazon.com/images/P/0439136369.01.LZZZZZZZ.jpg'

# %%
# extract book names
books_names = []
for idx in suggestion[0]:
    books_names.append(book_names[idx])
books_names
# Out:
# ['harry potter goblet fire ( book 4 )',
#  'harry potter prisoner azkaban ( book 3 )',
#  'harry potter chamber secrets ( book 2 )',
#  'harry potter order phoenix ( book 5 )',
#  "harry potter sorcerer 's stone ( book 1 )",
#  "harry potter sorcerer 's stone ( harry potter ( paperback ) )"]

# %%
# extract all image-urls
image_urls = []
for book in books_names:
    ids = np.where(book_ratings["title"] == book)[0][0]
    image_urls.append(book_ratings.iloc[ids]["image-url"])
image_urls
# Out:
# ['http://images.amazon.com/images/P/0439139597.01.LZZZZZZZ.jpg',
#  'http://images.amazon.com/images/P/0439136369.01.LZZZZZZZ.jpg',
#  'http://images.amazon.com/images/P/0439064872.01.LZZZZZZZ.jpg',
#  'http://images.amazon.com/images/P/043935806X.01.LZZZZZZZ.jpg',
#  'http://images.amazon.com/images/P/043936213X.01.LZZZZZZZ.jpg',
#  'http://images.amazon.com/images/P/059035342X.01.LZZZZZZZ.jpg']

# %%
import pickle

pickle.dump(model, open("artifacts/model.pkl", "wb"))
pickle.dump(book_names, open("artifacts/book_names.pkl", "wb"))
pickle.dump(book_ratings, open("artifacts/book_ratings.pkl", "wb"))
pickle.dump(book_pivot, open("artifacts/book_pivot.pkl", "wb"))
